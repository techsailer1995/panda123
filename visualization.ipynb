# %% [markdown]
# <a href="https://colab.research.google.com/github/techsailer1995/panda123/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#visiolization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
employee=files.upload()
# Out:
#      <input type="file" id="files-6c805d06-2023-40da-9277-90c144db20d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c805d06-2023-40da-9277-90c144db20d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
emp=pd.read_csv('employee.csv')
emp
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import numpy as np
year=np.arange(2000,2025)
print(year)
temp=np.random.randint(20,30,25)
print(temp)
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]
# [28 21 26 25 22 28 24 24 20 24 27 26 27 26 21 26 21 28 23 22 22 27 21 25
#  22]

# %%
fig=plt.figure(figsize=(8,5))
plt.plot(year,temp)
plt.xlim(1999,2025)
plt.ylim(15,35)
plt.xlabel('Year',size=15)
plt.ylabel('Average Temperature',size=15)
plt.title('Comparision of yearly average temp',size=20)
plt.suptitle('A line plot',size=25,y=1)
# Out:
# Text(0.5, 1, 'A line plot')

# %%
fig=plt.figure(figsize=(8,5))
plt.plot(year,temp)
plt.xlim(1999,2025)
plt.ylim(15,35)
plt.xlabel('Year',size=15)
plt.ylabel('Average Temperature',size=15)
plt.title('Comparision of yearly average temp',size=20)
plt.suptitle('A line plot',size=25,y=1)
# Out:
# Text(0.5, 1, 'A line plot')

# %%
fig=plt.figure(figsize=(8,5))
plt.plot(year,temp,'r*')
plt.xlim(1999,2025)
plt.ylim(15,35)
plt.xlabel('Year',size=15)
plt.ylabel('Average Temperature',size=15)
plt.title('Comparision of yearly average temp',size=20)
plt.suptitle('A line plot',size=25,y=1)
# Out:
# Text(0.5, 1, 'A line plot')

# %%
fig=plt.figure(figsize=(8,5))
plt.plot(year,temp,'g*-')
plt.xlim(1999,2025)
plt.ylim(15,35)
plt.xlabel('Year',size=15)
plt.ylabel('Average Temperature',size=15)
plt.title('Comparision of yearly average temp',size=20)
plt.suptitle('A line plot',size=25,y=1)
# Out:
# Text(0.5, 1, 'A line plot')

# %%
pd.crosstab(emp['Department'],emp['BusinessTravel ']).plot(kind='bar',color=['green','red','blue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BusinessTravel '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
pd.crosstab(emp['Department'],emp['Attrition'])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(emp['Department'],emp['Attrition']).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab(emp['Department'],emp['Attrition']).plot(kind='bar',color=['green','red'])
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab(emp['Department'],emp['TrainingTimesLastYear ']).plot(kind='bar',color=['green'
,'red','blue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TrainingTimesLastYear '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(emp['Department'],emp['TrainingTimesLastYear ']).plot(kind='bar',color=['green'
,'red','blue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TrainingTimesLastYear '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(emp['Department'],emp['BusinessTravel ']).plot(kind='bar',color=['green','red','blue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BusinessTravel '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pd.crosstab(emp['Department'],emp['Attrition']).plot(kind='bar',color=['green','red'])

# %%
emp['EducationField'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
pd.crosstab(emp['EducationField'].value_counts().plot(kind='pie',autopct='%1.2f%%',color=['red','green','pink','yellow','purple','blue']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-db4b3fd3133a> in <cell line: 1>()
# ----> 1 pd.crosstab(emp['EducationField'].value_counts().plot(kind='pie',autopct='%1.2f%%',color=['red','green','pink','yellow','purple','blue']))
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
emp.groupby('EducationField')['MonthlyIncome'].mean()
# Out:
# EducationField
# Human Resources     7241.148148
# Life Sciences       6463.288779
# Marketing           7348.584906
# Medical             6510.036638
# Other               6071.548780
# Technical Degree    5758.303030
# Name: MonthlyIncome, dtype: float64

# %%
emp.groupby('EducationaField')['MonthlyIncome'].sum().plot(kind='pie',autopct='%1.2f%%')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-50705bfeac2e> in <cell line: 1>()
# ----> 1 emp.groupby('EducationaField')['MonthlyIncome'].sum().plot(kind='pie',autopct='%1.2f%%')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8250         axis = self._get_axis_number(axis)
#    8251
# -> 8252         return DataFrameGroupBy(
#    8253             obj=self,
#    8254             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     929
#     930         if grouper is None:
# --> 931             grouper, exclusions, obj = get_grouper(
#     932                 obj,
#     933                 keys,
#
# ...

# %%
emp
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
plt.hist(emp['DailyRate'])
# Out:
# (array([147., 140., 137., 169., 140., 147., 127., 162., 158., 143.]),
#  array([ 102. ,  241.7,  381.4,  521.1,  660.8,  800.5,  940.2, 1079.9,
#         1219.6, 1359.3, 1499. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
np.arange(100,1600,200),
plt.hist(emp['DailyRate'],bins=np.arange(100,1600,200),edgecolor='magenta',facecolor='lightgreen',rwidth=0.9)
# Out:
# (array([194., 210., 243., 193., 197., 214., 219.]),
#  array([ 100.,  300.,  500.,  700.,  900., 1100., 1300., 1500.]),
#  <BarContainer object of 7 artists>)

# %%
import numpy as np
print(min(emp['DailyRate']))
print(max(emp['DailyRate']))
intevals=np.linspace(min(emp['DailyRate']),max(emp['DailyRate']),11)
print()
plt.hist(emp['DailyRate'])
# Out:
# 102
# 1499
# (array([147., 140., 137., 169., 140., 147., 127., 162., 158., 143.]),
#  array([ 102. ,  241.7,  381.4,  521.1,  660.8,  800.5,  940.2, 1079.9,
#         1219.6, 1359.3, 1499. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.subplots(4)
plt.subplots(2,2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
plt.scatter(emp['DistanceFromHome'],emp['DailyRate'])
plt.xlabel('distance from home',size=15)
plt.xlabel('daily wage )

# %%
from google.colab import files
store=files.upload()
# Out:
#      <input type="file" id="files-30f1088a-7292-48e0-adc0-8d206264c298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30f1088a-7292-48e0-adc0-8d206264c298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
store=pd.read_excel('Sample - Superstore.xls',sheet_name='Orders')
store
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2020-103800 2020-01-03 2020-01-07  Standard Class
# 1           2  US-2020-112326 2020-01-04 2020-01-08  Standard Class
# 2           3  US-2020-112326 2020-01-04 2020-01-08  Standard Class
# 3           4  US-2020-112326 2020-01-04 2020-01-08  Standard Class
# 4           5  US-2020-141817 2020-01-05 2020-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2023-143259 2023-12-30 2024-01-03  Standard Class
# 10190   10191  US-2023-115427 2023-12-30 2024-01-03  Standard Class
# 10191   10192  US-2023-156720 2023-12-30 2024-01-03  Standard Class
# 10192   10193  US-2023-143259 2023-12-30 2024-01-03  Standard Class
# 10193   10194  CA-2023-143500 2023-12-30 2024-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
plt.scatter(store['Sales'],store['Profit'])
plt.xlabel('sales',size=15)
plt.ylabel('profit',size=15)
# Out:
# Text(0, 0.5, 'profit')

# %%
plt.scatter(store['Sales'],store['Profit'])
plt.xlabel('sales',size=15)
plt.ylabel('profit',size=15)
plt.suptitle('Sales v/s Profit',size=20,)
# Out:
# Text(0.5, 0.98, 'Sales v/s Profit')

# %%
plt.scatter(store['Discount'],store['Profit'])
plt.xlabel('discount',size=15)
plt.ylabel('profit',size=15)
plt.suptitle('discount v/s Profit',size=15,)
# Out:
# Text(0.5, 0.98, 'discount v/s Profit')

# %%
import seaborn as sb

# %%
sb.stripplot(y=emp['Age'],size=5,jitter=True)
# Out:
# <Axes: ylabel='Age'>

# %%
sb.stripplot(y=emp['Gender'],size=5,jitter=True)
# Out:
# <Axes: ylabel='Gender'>

# %%
sb.stripplot(x=emp['Department'],y=emp['Age'],size=5,jitter=True)
# Out:
# <Axes: xlabel='Department', ylabel='Age'>

# %%
palette={'Sales':'green','Reseaech & Development':'red','Human Resources':'yellow'}

# %%
sb.stripplot(x=emp['Department'],y=emp['Age'],size=5,jitter=True,
palette={'Sales':'green','Research & Development':'red','Human Resources':'yellow'})
# Out:
# <ipython-input-32-df13e24227e9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.stripplot(x=emp['Department'],y=emp['Age'],size=5,jitter=True,
# <Axes: xlabel='Department', ylabel='Age'>

# %%
sb.scatterplot(x=emp['Age'],y=emp['TotalWorkingYears'],hue= emp['Gender'],
   palette={'female':'pink', 'males':'red'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-8f9c1ab2cad0> in <cell line: 1>()
# ----> 1 sb.scatterplot(x=emp['Age'],y=emp['TotalWorkingYears'],hue= emp['Gender'],
#       2    palette={'female':'pink', 'males':'red'})
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     614     )
#     615
# --> 616     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     617     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#     618     p.map_style(markers=markers, order=style_order)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in map_hue(self, palette, order, norm, saturation)
#     836
# ...

# %%
sb.barplot(x=emp['EducationField'],y=emp['MonthlyIncome'],estimator='max')
# Out:
# <Axes: xlabel='EducationField', ylabel='MonthlyIncome'>

# %%
sb.scatterplot(x=emp['Age'],y=emp['TotalWorkingYears'],hue=emp['Gender'],
               palette={'Female':'fuchsia','Male':'cyan'},style=emp['Gender'],
               markers={'Female':'*','Male':'*'})
# Out:
# <Axes: xlabel='Age', ylabel='TotalWorkingYears'>

# %%
df=sb.load_dataset('glue')
df
# Out:
#           Model  Year      Encoder  Task  Score
# 0         ERNIE  2019  Transformer  CoLA   75.5
# 1            T5  2019  Transformer  CoLA   71.6
# 2       RoBERTa  2019  Transformer  CoLA   67.8
# 3          BERT  2018  Transformer  CoLA   60.5
# 4   BiLSTM+ELMo  2018         LSTM  CoLA   32.1
# ..          ...   ...          ...   ...    ...
# 59         BERT  2018  Transformer   RTE   70.1
# 60  BiLSTM+ELMo  2018         LSTM   RTE   57.4
# 61  BiLSTM+CoVe  2017         LSTM   RTE   52.7
# 62  BiLSTM+Attn  2017         LSTM   RTE   58.4
# 63       BiLSTM  2017         LSTM   RTE   57.4
#
# [64 rows x 5 columns]

# %%
emp_heatmap=emp.pivot_table(index='JobRole',columns='BusinessTravel',values='DailyRate')
sb.heatmap(emp_heatmap)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='JobRole'>

# %%
sb.pairplot(emp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-d4f657cc1c9c> in <cell line: 1>()
# ----> 1 sb.pairplot(emp)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ...

# %%
sb.pairplot(iris)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-d4f657cc1c9c> in <cell line: 1>()
# ----> 1 sb.pairplot(emp)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ...

# %%
sb.pairplot(iris,hue='species')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-590e72946283> in <cell line: 1>()
# ----> 1 sb.pairplot(iris,hue='species')
#
# NameError: name 'iris' is not defined

# %%
import dataset('iris')
# Out:
#   File "<ipython-input-79-753859515f38>", line 1
#     import dataset('iris')
#                   ^
# SyntaxError: invalid syntax
